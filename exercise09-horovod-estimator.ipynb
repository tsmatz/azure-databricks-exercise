# %% [markdown]
# # Exercise 09 : Horovod Estimator on Databricks Runtime for ML
# Before starting,
#
# 1. Put the [parquet dataset for MNIST (for both training and test)](https://github.com/tsmatz/azure-databricks-exercise) in your blob container. (See "Exercise 05 : Working with Azure services".)
# 2. Use Databricks Runtime for ML (ML Beta) for your cluster

# %%
df = spark.read.parquet("/mnt/testblob/mnist_training_parquet")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
import tensorflow as tf
import horovod.tensorflow as hvd
from pyspark.sql.types import *
from sparkdl.estimators.horovod_estimator.estimator import HorovodEstimator
import math

def model_fn(features, labels, mode):
  images = features['image']
  images = tf.reshape(images, shape=[-1, 784])
  
  with tf.name_scope('hidden1'):
    weights = tf.Variable(
      tf.truncated_normal(
        [784, 128],
        stddev=1.0 / math.sqrt(float(784))),
      name='weights')
    biases = tf.Variable(
      tf.zeros([128]),
      name='biases')
    hidden1 = tf.nn.relu(tf.matmul(images, weights) + biases)
  with tf.name_scope('hidden2'):
    weights = tf.Variable(
      tf.truncated_normal(
        [128, 64],
        stddev=1.0 / math.sqrt(float(128))),
      name='weights')
    biases = tf.Variable(
      tf.zeros([64]),
      name='biases')
    hidden2 = tf.nn.relu(tf.matmul(hidden1, weights) + biases)
  with tf.name_scope('softmax_linear'):
    weights = tf.Variable(
      tf.truncated_normal(
        [64, 10],
        stddev=1.0 / math.sqrt(float(64))),
      name='weights')
    biases = tf.Variable(
      tf.zeros([10]),
      name='biases')
    logits = tf.matmul(hidden2, weights) + biases

  predicted_indices = tf.argmax(input=logits, axis=1, name="predicted_indices")   
  
  if mode == tf.estimator.ModeKeys.PREDICT:
    serving_key = tf.saved_model.signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY
    predictions = {
      "classes": predicted_indices,
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor"),
    }
    export_outputs = {serving_key: tf.estimator.export.PredictOutput(predictions)}
    return tf.estimator.EstimatorSpec(
      mode=mode,
      predictions=predictions,
      export_outputs=export_outputs)
  
  onehot_labels = tf.one_hot(indices=tf.cast(labels, tf.int32), depth=10)
  loss = tf.losses.softmax_cross_entropy(onehot_labels=onehot_labels, logits=logits)
  
  if mode == tf.estimator.ModeKeys.TRAIN:
    logging_hooks = [tf.train.LoggingTensorHook(tensors={"predictions": "predicted_indices"}, every_n_iter=5000)]
    optimizer = tf.train.MomentumOptimizer(
      learning_rate=0.001 * hvd.size(), momentum=0.9)
    optimizer = hvd.DistributedOptimizer(optimizer)
    train_op = optimizer.minimize(
      loss=loss,
      global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(
      mode=mode,
      loss=loss,
      train_op=train_op,
      training_hooks=logging_hooks)

  if mode == tf.estimator.ModeKeys.EVAL:
    eval_metric_ops = {"accuracy": tf.metrics.accuracy(labels=labels, predictions=predicted_indices)}
    return tf.estimator.EstimatorSpec(
      mode=mode,
      loss=loss,
      eval_metric_ops=eval_metric_ops)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/local/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from &#96;float&#96; to &#96;np.floating&#96; is deprecated. In future, it will be treated as &#96;np.float64 == np.dtype(float).type&#96;.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# </div>

# %%
model_dir = "/tmp/model01"  # mounted dir is not allowed
dbutils.fs.rm(model_dir, recurse=True)

est = HorovodEstimator(
  modelFn=model_fn,
  featureMapping={"image": "image"},
  modelDir=model_dir,
  labelCol="label_col",
  batchSize=64,
  maxSteps=5000,
  isValidationCol="isVal",
  saveCheckpointsSecs=30)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import rand, when

# Set true as "isVal" for validation data
df_with_val = df.withColumn("isVal", when(rand() > 0.8, True).otherwise(False))
# Train and create transformer
transformer = est.fit(df_with_val)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">WARNING:tensorflow:Hit error when running nvidia-smi: [Errno 2] No such file or directory. Defaulting to running a single training process per machine.
# INFO:tensorflow:Running Horovod training command mpirun --allow-run-as-root -output-filename /tmp/model01 -np 3 -map-by slot -H 10.139.64.4:1,10.139.64.6:1,10.139.64.5:1 -bind-to none -x PROG_SPEC_PATH -x NCCL_DEBUG /databricks/python/bin/python /tmp/tmpkwtpjY/horovod_launcher.py
# ...

# %%
# Predict and output
test_df = spark.read.parquet("/mnt/testblob/mnist_test_parquet")
res = transformer.transform(test_df)
res.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+--------------------+---------+
# classes|       probabilities|               image|label_col|
# +-------+--------------------+--------------------+---------+
#       8|[5.787779E-7, 3.4...|[0.0, 0.0, 0.0, 0...|        8|
#       2|[5.0502595E-6, 2....|[0.0, 0.0, 0.0, 0...|        1|
#       3|[9.544723E-7, 5.5...|[0.0, 0.0, 0.0, 0...|        3|
#       9|[4.548108E-5, 1.0...|[0.0, 0.0, 0.0, 0...|        9|
#       4|[1.2883314E-8, 4....|[0.0, 0.0, 0.0, 0...|        4|
#       0|[0.75558853, 1.52...|[0.0, 0.0, 0.0, 0...|        0|
#       3|[3.0499802E-4, 0....|[0.0, 0.0, 0.0, 0...|        3|
# ...

# %% [markdown]
# # Exercise 02 : Structured Streaming

# %%
dbutils.fs.rm("/tmp/structured-streaming/events", recurse=True)
dbutils.fs.put(
  "/tmp/structured-streaming/events/file01.json",
  """{"event_name":"Open","event_time":1540601000}
{"event_name":"Open","event_time":1540601010}
{"event_name":"Fail","event_time":1540601020}
{"event_name":"Open","event_time":1540601030}
{"event_name":"Open","event_time":1540601040}
{"event_name":"Open","event_time":1540601050}
{"event_name":"Open","event_time":1540601060}
{"event_name":"Fail","event_time":1540601070}
{"event_name":"Open","event_time":1540601080}
{"event_name":"Open","event_time":1540601090}
""", True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 460 bytes.
# <span class="ansired">Out[</span><span class="ansired">1</span><span class="ansired">]: </span>True
# </div>

# %%
# %fs head /tmp/structured-streaming/events/file01.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&quot;event_name&quot;:&quot;Open&quot;,&quot;event_time&quot;:1540601000}
# {&quot;event_name&quot;:&quot;Open&quot;,&quot;event_time&quot;:1540601010}
# {&quot;event_name&quot;:&quot;Fail&quot;,&quot;event_time&quot;:1540601020}
# {&quot;event_name&quot;:&quot;Open&quot;,&quot;event_time&quot;:1540601030}
# {&quot;event_name&quot;:&quot;Open&quot;,&quot;event_time&quot;:1540601040}
# {&quot;event_name&quot;:&quot;Open&quot;,&quot;event_time&quot;:1540601050}
# {&quot;event_name&quot;:&quot;Open&quot;,&quot;event_time&quot;:1540601060}
# {&quot;event_name&quot;:&quot;Fail&quot;,&quot;event_time&quot;:1540601070}
# {&quot;event_name&quot;:&quot;Open&quot;,&quot;event_time&quot;:1540601080}
# {&quot;event_name&quot;:&quot;Open&quot;,&quot;event_time&quot;:1540601090}
#
# </div>

# %%
##### For Test !
# from pyspark.sql.types import *
# from pyspark.sql.functions import *

# test_schema = StructType([
#  StructField("event_name", StringType(), True),
#  StructField("event_time", TimestampType(), True)])
# test_df = (
#  spark
#    .read
#    .schema(test_schema)
#    .json("/tmp/structured-streaming/events/")
# )
# display(test_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_name</th><th>event_time</th></tr></thead><tbody><tr><td>Open</td><td>2018-10-27T00:43:20.000+0000</td></tr><tr><td>Open</td><td>2018-10-27T00:43:30.000+0000</td></tr><tr><td>Fail</td><td>2018-10-27T00:43:40.000+0000</td></tr><tr><td>Open</td><td>2018-10-27T00:43:50.000+0000</td></tr><tr><td>Open</td><td>2018-10-27T00:44:00.000+0000</td></tr><tr><td>Open</td><td>2018-10-27T00:44:10.000+0000</td></tr><tr><td>Open</td><td>2018-10-27T00:44:20.000+0000</td></tr><tr><td>Fail</td><td>2018-10-27T00:44:30.000+0000</td></tr><tr><td>Open</td><td>2018-10-27T00:44:40.000+0000</td></tr><tr><td>Open</td><td>2018-10-27T00:44:50.000+0000</td></tr></tbody></table></div>

# %%
# Create streaming dataframe
from pyspark.sql.types import *
from pyspark.sql.functions import *

read_schema = StructType([
  StructField("event_name", StringType(), True),
  StructField("event_time", TimestampType(), True)])
read_df = (
  spark
    .readStream                       
    .schema(read_schema)
    .option("maxFilesPerTrigger", 1)  # one file at a time
    .json("/tmp/structured-streaming/events/")
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# The following will continue to run as background jobs ...

# %%
# Write results in memory
query1 = (
  read_df
    .writeStream
    .format("memory")
    .queryName("read_simple")
    .start()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select event_name, date_format(event_time, "MMM-dd HH:mm") from read_simple order by event_time
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_name</th><th>date_format(event_time, MMM-dd HH:mm)</th></tr></thead><tbody><tr><td>Open</td><td>Oct-27 00:43</td></tr><tr><td>Open</td><td>Oct-27 00:43</td></tr><tr><td>Fail</td><td>Oct-27 00:43</td></tr><tr><td>Open</td><td>Oct-27 00:43</td></tr><tr><td>Open</td><td>Oct-27 00:44</td></tr><tr><td>Open</td><td>Oct-27 00:44</td></tr><tr><td>Open</td><td>Oct-27 00:44</td></tr><tr><td>Fail</td><td>Oct-27 00:44</td></tr><tr><td>Open</td><td>Oct-27 00:44</td></tr><tr><td>Open</td><td>Oct-27 00:44</td></tr></tbody></table></div>

# %% [markdown]
# Publish next event into folder and see the previous results again ! (See how streaming is displayed in the previous background job.)

# %%
# Add new file in front end and see above result again
dbutils.fs.put(
  "/tmp/structured-streaming/events/file02.json",
  """{"event_name":"Open","event_time":1540601100}
{"event_name":"Open","event_time":1540601110}
{"event_name":"Fail","event_time":1540601120}
{"event_name":"Open","event_time":1540601130}
{"event_name":"Open","event_time":1540601140}
{"event_name":"Open","event_time":1540601150}
{"event_name":"Open","event_time":1540601160}
{"event_name":"Fail","event_time":1540601170}
{"event_name":"Open","event_time":1540601180}
{"event_name":"Open","event_time":1540601190}
""", True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 460 bytes.
# <span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>True
# </div>

# %%
# Windowing analysis
group_df = (                 
  read_df
    .groupBy(
      read_df.event_name, 
      window(read_df.event_time, "1 minute"))
    .count()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# The following will also continue to run as background jobs ...

# %%
query2 = (
  group_df
    .writeStream
    .format("memory")
    .queryName("read_counts")
    .outputMode("complete")
    .start()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select event_name, date_format(window.end, "MMM-dd HH:mm") as event_time, count from read_counts order by event_time, event_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_name</th><th>event_time</th><th>count</th></tr></thead><tbody><tr><td>Fail</td><td>Oct-27 00:44</td><td>1</td></tr><tr><td>Open</td><td>Oct-27 00:44</td><td>3</td></tr><tr><td>Fail</td><td>Oct-27 00:45</td><td>1</td></tr><tr><td>Open</td><td>Oct-27 00:45</td><td>5</td></tr><tr><td>Fail</td><td>Oct-27 00:46</td><td>1</td></tr><tr><td>Open</td><td>Oct-27 00:46</td><td>5</td></tr><tr><td>Fail</td><td>Oct-27 00:47</td><td>1</td></tr><tr><td>Open</td><td>Oct-27 00:47</td><td>3</td></tr></tbody></table></div>

# %% [markdown]
# Publish next event into folder and see the previous results again ! (See how streaming is displayed in the previous background job.)

# %%
# Add new file in front end and see above result again
dbutils.fs.put(
  "/tmp/structured-streaming/events/file03.json",
  """{"event_name":"Open","event_time":1540601200}
{"event_name":"Open","event_time":1540601210}
{"event_name":"Fail","event_time":1540601220}
{"event_name":"Open","event_time":1540601230}
{"event_name":"Open","event_time":1540601240}
{"event_name":"Open","event_time":1540601250}
{"event_name":"Open","event_time":1540601260}
{"event_name":"Fail","event_time":1540601270}
{"event_name":"Open","event_time":1540601280}
{"event_name":"Open","event_time":1540601290}
""", True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 460 bytes.
# <span class="ansired">Out[</span><span class="ansired">7</span><span class="ansired">]: </span>True
# </div>

# %% [markdown]
# After completed, cancel (stop) previous jobs.
